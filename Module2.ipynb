# %%
#Import Dependecies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as py
import numpy as np
import seaborn as sns
from sklearn import preprocessing 
from sklearn import datasets

# %%
# File to Load 
Iris_Data_Load = Path("iris.data")

# Read Iris Data File and store into Pandas DataFrames
Iris_Data = pd.read_csv(Iris_Data_Load)

#Assign the Column Names(Attributes)
Iris_Data.columns=["Sepal_Length","Sepal_Width","Petal_Length","Petal_Width","Class_Iris"]

# Display the dataset
Iris_Data.head(5)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Class_Iris
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
#Statistical Summaries
Cleaned_Iris_Df=Iris_Data.dropna()
Stat_Iris=Cleaned_Iris_Df.describe()
Stat_Iris.head()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000

# %%
# Generate a bar plot showing 
Petal_Width_Mean= Iris_Data.groupby('Class_Iris')['Petal_Width'].mean()
# Plot the data
plt.figure(figsize=(6,4))
Petal_Width_Mean.plot(kind='bar', color='darkblue')

# Set plot titles and labels
plt.title("The Mean 'petal_width' by Species")
plt.ylabel('Petal_Width')
plt.xlabel('Class_Iris')

# Display the plot
plt.show()

# %%
#Scatter plot to show the comparison between Sepal Length and Width
sns.scatterplot(data=Iris_Data, x='Sepal_Length', y='Sepal_Width',hue='Class_Iris')

#Show the plot
plt.show()

# %%
#Scatter plot to show the comparison between Sepal Length and Width
sns.barplot(data=Iris_Data, x='Class_Iris', y='Sepal_Width',hue='Class_Iris')

#Show the plot
plt.show()

# %%
Sepal_Length= np.random.normal(Iris_Data.select_dtypes(include=[np.number]))

plt.hist(Sepal_Length)
plt.show()

# %%
sepal_length=np.log(Iris_Data["Sepal_Length"])
plt.hist(sepal_length,bins=20, color='purple', edgecolor='black', alpha= 0.4)
plt.xlabel("sepal_length")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()
